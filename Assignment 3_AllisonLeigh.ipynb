# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd

# %%
#Create empty lists to store the data we are about to collect from the website
#We would like to collect the names of the cars, the mileage, the price, the rating, the number of reviews the car received

car_name = []
car_mileage = []
car_price = []

# %%
#We need to create a variable to store the url of the website, I'm calling this variable website_url. We then need to send a request to the website
#and scrape multiple pages

for i in range(1,2):
    website_url ="https://www.truecar.com/used-cars-for-sale/listings/dodge/charger/location-north-haven-ct/?excludeExpandedDelivery=true&searchRadius=50" + str(i)
    #make request to the website
    web_request = requests.get(website_url, headers={'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/85.0.4183.102 Safari/537.36'})
    
    # Create an object to store the html elements of the request
    soup = BeautifulSoup(web_request.content,'html.parser')
    
    # Create a list that contains the results of the web page
    results_list = soup.find_all('div', {'class':'flex w-full flex-col h-full'})
    
    for i in results_list:
    
        #get the names of the cars. If the name of the car is not present, append 'n/a' to the list
        try:
            car_name.append(i.find('h2').get_text())
        except:
            car_name.append('n/a')

        #get the mileage of the cars
        try:
            car_mileage.append(i.find('div', {'data-test': 'vehicleMileage'}).get_text())
        except:
            car_mileage.append('n/a')

        #get the price of the car
        try:
            car_price.append(i.find('span', {'data-test': 'vehicleCardPricingPrice'}).get_text())
        except:
            car_price.append('n/a')

# %%
# Create a DataFrame

car_info = pd.DataFrame({'Name': car_name, 'Mileage': car_mileage, 'Price': car_price})

# %%
#print the DataFrame
car_info.head()
# Out:
#                              Name       Mileage     Price
# 0  Used 2022 DodgeCharger SXT RWD  58,269 miles  $14,088
# 1   Used 2023 DodgeCharger GT RWD  51,533 miles  $20,294
# 2  Used 2020 DodgeCharger SXT RWD  90,521 miles  $13,000
# 3   Used 2016 DodgeCharger SE RWD  26,400 miles  $14,995
# 4   Used 2023 DodgeCharger GT RWD  55,230 miles  $16,471

# %%
#Let's clean the data frame

#The first thing we should do is to edit the Reviews column

car_info['Mileage'] = car_info['Mileage'].apply(lambda x:x.replace('miles', '')) #remove 'mi' from the mileage column
car_info['Mileage'] = car_info['Mileage'].apply(lambda x:x.replace('k', '000')) #remove 'k' from the mileage column
car_info['Price'] = car_info['Price'].apply(lambda x:x.replace('$', '')) # remove the $ from the Price column
car_info['Price'] = car_info['Price'].apply(lambda x:x.replace(',', '')) #remove the ',' from the Price column

# %%
car_info.head()
# Out:
#                              Name  Mileage   Price
# 0  Used 2022 DodgeCharger SXT RWD  58,269   14088
# 1   Used 2023 DodgeCharger GT RWD  51,533   20294
# 2  Used 2020 DodgeCharger SXT RWD  90,521   13000
# 3   Used 2016 DodgeCharger SE RWD  26,400   14995
# 4   Used 2023 DodgeCharger GT RWD  55,230   16471

# %%
#The Name column has a lot of important data on the Year, Company, Vehicle make and model.
# Use regex to split the 'Name' column into 4 parts: Stock type, Year, Brand, and the rest
#(\w+): Matches the stock type (e.g., "Used").
#(\d{4}): Matches the year (e.g., "2021").
#([A-Za-z]+): Matches the brand (e.g., "Toyota").
#(.*): Captures the rest of the string (e.g., "Tacoma SR5 Double Cab 5' Bed V6 4WD Automatic").

car_info[['Stock type', 'Year', 'Brand', 'Rest']] = car_info['Name'].str.extract(r'(\w+)\s(\d{4})\s([A-Za-z]+)(.*)')

# %%
car_info.head()
# Out:
#                              Name  Mileage   Price Stock type  Year  \
# 0  Used 2022 DodgeCharger SXT RWD  58,269   14088        Used  2022
# 1   Used 2023 DodgeCharger GT RWD  51,533   20294        Used  2023
# 2  Used 2020 DodgeCharger SXT RWD  90,521   13000        Used  2020
# 3   Used 2016 DodgeCharger SE RWD  26,400   14995        Used  2016
# 4   Used 2023 DodgeCharger GT RWD  55,230   16471        Used  2023
#
#           Brand      Rest
# 0  DodgeCharger   SXT RWD
# 1  DodgeCharger    GT RWD
# 2  DodgeCharger   SXT RWD
# 3  DodgeCharger    SE RWD
# 4  DodgeCharger    GT RWD

# %%
# For my example, the car name and model are displayed in the brand column. I will use regex to extract the Brand and Model
#NOTE: This may not be the case for you, if it isn't so not run this cell. I suggest you look at your data

#We use the regular expression r'([A-Za-z]+)([A-Z][a-zA-Z]*)' to capture:
#([A-Za-z]+): The first part of the string (brand), which is made up of any sequence of letters.
#([A-Z][a-zA-Z]*): The second part (model), which starts with a capital letter followed by more letters.

car_info[['Make', 'Model']] = car_info['Brand'].str.extract(r'([A-Za-z]+)([A-Z][a-zA-Z]*)')

car_info
# Out:
#                                                  Name   Mileage   Price  \
# 0                      Used 2022 DodgeCharger SXT RWD   58,269   14088
# 1                       Used 2023 DodgeCharger GT RWD   51,533   20294
# 2                      Used 2020 DodgeCharger SXT RWD   90,521   13000
# 3                       Used 2016 DodgeCharger SE RWD   26,400   14995
# 4                       Used 2023 DodgeCharger GT RWD   55,230   16471
# 5                      Used 2023 DodgeCharger SXT RWD      137   26190
# 6                      Used 2022 DodgeCharger SXT RWD   58,269   14088
# 7                       Used 2023 DodgeCharger GT RWD   56,630   16804
# 8                       Used 2023 DodgeCharger GT RWD   50,480   17741
# 9                      Used 2022 DodgeCharger SXT RWD   48,223   17985
# 10                      Used 2023 DodgeCharger GT RWD   51,533   20294
# 11                     Used 2022 DodgeCharger SXT RWD   59,297   16298
# 12                      Used 2023 DodgeCharger GT RWD   37,392   19495
# 13                      Used 2022 DodgeCharger GT RWD   61,065   17219
# 14                     Used 2022 DodgeCharger SXT RWD   59,194   15227
# 15                     Used 2022 DodgeCharger SXT RWD   55,328   16099
# 16                     Used 2021 DodgeCharger R/T RWD   29,180   24900
# 17      Used 2021 DodgeCharger Scat Pack Widebody RWD   30,035   38990
# 18                      Used 2021 DodgeCharger GT AWD  116,868   17088
# 19                     Used 2022 DodgeCharger SXT RWD   58,924   16498
# 20                     Used 2023 DodgeCharger SXT AWD    2,546   31125
# 21                      Used 2022 DodgeCharger GT AWD   10,821   29465
# 22                      Used 2022 DodgeCharger GT RWD   52,851   17990
# 23                     Used 2020 DodgeCharger SXT RWD   90,521   13000
# 24                     Used 2021 DodgeCharger SXT RWD   62,654   16595
# 25                     Used 2022 DodgeCharger SXT RWD   50,776   18349
# 26      Used 2023 DodgeCharger Scat Pack Widebody RWD   20,652   46977
# 27    Used 2022 DodgeCharger SRT Hellcat Widebody RWD   30,350   59750
# 28  Used 2023 DodgeCharger SRT Hellcat Widebody Ja...   26,752   62850
# 29                     Used 2021 DodgeCharger R/T RWD   30,799   25995
# 30                     Used 2023 DodgeCharger SXT RWD   19,962   21700
# 31                      Used 2023 DodgeCharger GT RWD   51,945   20495
# 32                     Used 2021 DodgeCharger SXT RWD   75,641   15789
#
#    Stock type  Year         Brand                                 Rest   Make  \
# 0        Used  2022  DodgeCharger                              SXT RWD  Dodge
# 1        Used  2023  DodgeCharger                               GT RWD  Dodge
# 2        Used  2020  DodgeCharger                              SXT RWD  Dodge
# 3        Used  2016  DodgeCharger                               SE RWD  Dodge
# 4        Used  2023  DodgeCharger                               GT RWD  Dodge
# 5        Used  2023  DodgeCharger                              SXT RWD  Dodge
# 6        Used  2022  DodgeCharger                              SXT RWD  Dodge
# 7        Used  2023  DodgeCharger                               GT RWD  Dodge
# 8        Used  2023  DodgeCharger                               GT RWD  Dodge
# 9        Used  2022  DodgeCharger                              SXT RWD  Dodge
# 10       Used  2023  DodgeCharger                               GT RWD  Dodge
# 11       Used  2022  DodgeCharger                              SXT RWD  Dodge
# 12       Used  2023  DodgeCharger                               GT RWD  Dodge
# 13       Used  2022  DodgeCharger                               GT RWD  Dodge
# 14       Used  2022  DodgeCharger                              SXT RWD  Dodge
# 15       Used  2022  DodgeCharger                              SXT RWD  Dodge
# 16       Used  2021  DodgeCharger                              R/T RWD  Dodge
# 17       Used  2021  DodgeCharger               Scat Pack Widebody RWD  Dodge
# 18       Used  2021  DodgeCharger                               GT AWD  Dodge
# 19       Used  2022  DodgeCharger                              SXT RWD  Dodge
# 20       Used  2023  DodgeCharger                              SXT AWD  Dodge
# 21       Used  2022  DodgeCharger                               GT AWD  Dodge
# 22       Used  2022  DodgeCharger                               GT RWD  Dodge
# 23       Used  2020  DodgeCharger                              SXT RWD  Dodge
# 24       Used  2021  DodgeCharger                              SXT RWD  Dodge
# 25       Used  2022  DodgeCharger                              SXT RWD  Dodge
# 26       Used  2023  DodgeCharger               Scat Pack Widebody RWD  Dodge
# 27       Used  2022  DodgeCharger             SRT Hellcat Widebody RWD  Dodge
# 28       Used  2023  DodgeCharger   SRT Hellcat Widebody Jailbreak RWD  Dodge
# 29       Used  2021  DodgeCharger                              R/T RWD  Dodge
# 30       Used  2023  DodgeCharger                              SXT RWD  Dodge
# 31       Used  2023  DodgeCharger                               GT RWD  Dodge
# 32       Used  2021  DodgeCharger                              SXT RWD  Dodge
#
#       Model
# 0   Charger
# 1   Charger
# 2   Charger
# 3   Charger
# 4   Charger
# 5   Charger
# 6   Charger
# 7   Charger
# 8   Charger
# 9   Charger
# 10  Charger
# 11  Charger
# 12  Charger
# 13  Charger
# 14  Charger
# 15  Charger
# 16  Charger
# 17  Charger
# 18  Charger
# 19  Charger
# 20  Charger
# 21  Charger
# 22  Charger
# 23  Charger
# 24  Charger
# 25  Charger
# 26  Charger
# 27  Charger
# 28  Charger
# 29  Charger
# 30  Charger
# 31  Charger
# 32  Charger

# %%
#For my example, there are a few NaNs in the Make and Model columns, I need to replace these with the values Toyota, Tacoma

# Fill NaN values in the 'Brand' column with 'Toyota'
# car_info['Make'].fillna('Toyota', inplace=True)

# Fill NaN values in the 'Model' column with 'Tacoma'
# car_info['Model'].fillna('Tacoma', inplace=True)

car_info.fillna({'Make': 'Toyota', 'Model': 'Tacoma'}, inplace=True)

# Display the DataFrame
car_info.head()
# Out:
#                              Name  Mileage   Price Stock type  Year  \
# 0  Used 2022 DodgeCharger SXT RWD  58,269   14088        Used  2022
# 1   Used 2023 DodgeCharger GT RWD  51,533   20294        Used  2023
# 2  Used 2020 DodgeCharger SXT RWD  90,521   13000        Used  2020
# 3   Used 2016 DodgeCharger SE RWD  26,400   14995        Used  2016
# 4   Used 2023 DodgeCharger GT RWD  55,230   16471        Used  2023
#
#           Brand      Rest   Make    Model
# 0  DodgeCharger   SXT RWD  Dodge  Charger
# 1  DodgeCharger    GT RWD  Dodge  Charger
# 2  DodgeCharger   SXT RWD  Dodge  Charger
# 3  DodgeCharger    SE RWD  Dodge  Charger
# 4  DodgeCharger    GT RWD  Dodge  Charger

# %%
# Drop the column Name and its no longer needed
car_info = car_info.drop(["Name"], axis = 1)
car_info = car_info.drop(["Rest"], axis = 1)
car_info = car_info.drop(["Brand"], axis = 1)

# %%
car_info
# Out:
#      Mileage   Price Stock type  Year   Make    Model
# 0    58,269   14088        Used  2022  Dodge  Charger
# 1    51,533   20294        Used  2023  Dodge  Charger
# 2    90,521   13000        Used  2020  Dodge  Charger
# 3    26,400   14995        Used  2016  Dodge  Charger
# 4    55,230   16471        Used  2023  Dodge  Charger
# 5       137   26190        Used  2023  Dodge  Charger
# 6    58,269   14088        Used  2022  Dodge  Charger
# 7    56,630   16804        Used  2023  Dodge  Charger
# 8    50,480   17741        Used  2023  Dodge  Charger
# 9    48,223   17985        Used  2022  Dodge  Charger
# 10   51,533   20294        Used  2023  Dodge  Charger
# 11   59,297   16298        Used  2022  Dodge  Charger
# 12   37,392   19495        Used  2023  Dodge  Charger
# 13   61,065   17219        Used  2022  Dodge  Charger
# 14   59,194   15227        Used  2022  Dodge  Charger
# 15   55,328   16099        Used  2022  Dodge  Charger
# 16   29,180   24900        Used  2021  Dodge  Charger
# 17   30,035   38990        Used  2021  Dodge  Charger
# 18  116,868   17088        Used  2021  Dodge  Charger
# 19   58,924   16498        Used  2022  Dodge  Charger
# 20    2,546   31125        Used  2023  Dodge  Charger
# 21   10,821   29465        Used  2022  Dodge  Charger
# 22   52,851   17990        Used  2022  Dodge  Charger
# 23   90,521   13000        Used  2020  Dodge  Charger
# 24   62,654   16595        Used  2021  Dodge  Charger
# 25   50,776   18349        Used  2022  Dodge  Charger
# 26   20,652   46977        Used  2023  Dodge  Charger
# 27   30,350   59750        Used  2022  Dodge  Charger
# 28   26,752   62850        Used  2023  Dodge  Charger
# 29   30,799   25995        Used  2021  Dodge  Charger
# 30   19,962   21700        Used  2023  Dodge  Charger
# 31   51,945   20495        Used  2023  Dodge  Charger
# 32   75,641   15789        Used  2021  Dodge  Charger

# %%
#You can export the DataFrame to excel if you choose to proceed with excel
car_info.to_excel('multiple_pages.xlsx', index = False)

# %%
#You can export the DataFrame to a csv file if needed
car_info.to_csv('multiple_pages.csv', index = False)
